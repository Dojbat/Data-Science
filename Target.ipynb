# %%
from matplotlib import *
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("April Action.csv")
rf = pd.read_csv("Target.csv")
vf = pd.read_csv("March Action.csv")
af = pd.read_csv("March Target.csv")

de = []
ew = []
plt.figure(figsize=(20,10))
for t in rf['User']:
    de.append(t)
for r in rf['date']:
    ew.append(r)
plt.title("March Action data")
plt.plot(ew,de)
plt.show()

# %%
q = []
e = []
plt.figure(figsize=(20,10))
for t in rf['New user']:
    q.append(t)
for r in rf['date']:
    e.append(r)
plt.title("March Action data")
plt.plot(e,q)
plt.show()

# %%
qe = []
eq = []
plt.figure(figsize=(20,10))
for t in rf['Session']:
    qe.append(t)
for r in rf['date']:
    eq.append(r)
plt.title("March Action data")
plt.plot(eq,qe)
plt.show()

# %%
u = []
m = []
plt.figure(figsize=(20,10))
for t in rf['Session per user']:
    u.append(t)
for r in rf['date']:
    m.append(r)
plt.title("March Action data")
plt.plot(m,u)
plt.show()

# %%
x = []
y = []
plt.figure(figsize=(30,10))
for t in rf['page open']:
    x.append(t)
for r in rf['date']:
    y.append(r)
plt.title("March Action data")
plt.plot(y,x)
plt.show()

# %%
a = []
b = []
plt.figure(figsize=(30,10))
for t in rf['Session/page']:
    a.append(t)
for r in rf['date']:
    b.append(r)
plt.title("March Action data")
plt.plot(b,a)
plt.show()

# %%
z = []
c = []
plt.figure(figsize=(30,10))
for t in rf['Session total time']:
    z.append(t)
for r in rf['date']:
    c.append(r)
plt.title("March Action data")
plt.plot(c,z)
plt.show()

# %%
k = []
l = []
plt.figure(figsize=(30,10))
for t in rf['Bounce rate']:
    k.append(t)
for r in rf['date']:
    l.append(r)
plt.title("March Action data")
plt.plot(l,k)
plt.show()
